# %%
import pandas as pd
import ast

# %%
# /home/trishalaswain/Downloads/SCP-1526-MONROE COUNTY HOSPITAL - FORSYTH-2023-02-01-2023-02-15.xlsx

# %%
df = pd.read_excel('/home/trishalaswain/Downloads/PH-HEMAG-Hollywood EMA Group-2023-04-01-2023-04-30.xlsx', index_col=False)

# %%
df['lastCodingDate'] = pd.to_datetime(df.lastCodingDate)

# %%
df.sort_values('lastCodingDate')
# Out:
#            id  physicianId            serviceDate         processingDate  \
# 2988  6102299        20003  2023-04-01 00:00:00.0  2023-04-02 01:43:10.0
# 3014  6102312        20003  2023-04-01 00:00:00.0  2023-04-02 01:43:28.0
# 2945  6102249        20003  2023-04-01 00:00:00.0  2023-04-02 01:41:21.0
# 3001  6102274        20003  2023-04-01 00:00:00.0  2023-04-02 01:42:40.0
# 3147  6078345        20003  2023-03-21 00:00:00.0  2023-04-21 01:42:34.0
# ...       ...          ...                    ...                    ...
# 577   6604218        20003  2023-04-25 00:00:00.0  2023-04-26 01:52:18.0
# 526   6604272        20003  2023-04-25 00:00:00.0  2023-04-26 01:56:46.0
# 516   6604261        20003  2023-04-25 00:00:00.0  2023-04-26 02:56:35.0
# 619   6604372        20003  2023-04-25 00:00:00.0  2023-04-26 02:02:45.0
# 746   6604609        20003  2023-04-25 00:00:00.0  2023-04-26 02:11:24.0
#
#               admissionDate  userId  processId      lastCodingDate    month  \
# ...

# %%
df = df[df.lastCodingDate>='2023-04-15']

# %%
df.accountNumber.to_excel('/home/trishalaswain/Downloads/Script_Testing/time_df.xlsx')
