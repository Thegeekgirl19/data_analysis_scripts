# %%
import pandas as pd
import ast
import re

# %%
df = pd.read_excel('/home/trishalaswain/Documents/AGS_PROJECTS/OCR_SERVICE/SCP_42/SCP_42_DUAL_DOCS/mappings.xlsx', index_col=False)

# %%
# df = df[['account', 'request_id', 'suggested', 'final', 'local_suggested']]

# %%
df.dropna(subset=['local_suggested'], inplace=True)

# %%
# df2.reindex()
# df.groupby(['account_number'], axis=0).agg(', '.join)

# %%
df.shape
# df.suggested = df.suggested.astype('str')
# df.final = df.final.astype('str')
# df.local_suggested = df.local_suggested.astype('int')
# Out:
# (1935, 5)

# %%
df.shape
# Out:
# (1935, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ocr_request_id', 'account_number', 'final_code',
#        'suggested_code', 'local_suggested'],
#       dtype='object')

# %%
# df.encDocIds = df.encDocIds.astype('str')

# %%
# df = df[~df.encDocIds.str.contains(',')]

# %%
df
# Out:
#       ocr_request_id  account_number  final_code  suggested_code  \
# 0            6675433        90188814       99285           99285
# 1            6675440        90188808       99284           99284
# 2            6675442        90188807       99285           99285
# 3            6675444        90188805       99291           99285
# 4            6675444        90188805       99285           99285
# ...              ...             ...         ...             ...
# 1930         6917619        90227081       99291           99291
# 1931         6917619        90227081       99285           99291
# 1932         6918839        90272706       99284           99284
# 1933         6922667        90415094       99284           99284
# 1934         6922666        90415173       99285           99284
#
#       local_suggested
# 0               99285
# 1               99284
# 2               99285
# 3               99285
# 4               99285
# ...               ...
# 1930            99285
# 1931            99285
# 1932            99285
# 1933            99285
# 1934            99285
#
# [1935 rows x 5 columns]

# %%
# for i,r in df.iterrows():
#     df.at[i, 'EANDM_Rejected'] = r['EANDM_Rejected'].replace(']', '').replace('[', '')
#     df.at[i, 'EANDM_Added'] = r['EANDM_Added'].replace(']', '').replace('[', '')
#     df.at[i, 'EANDM_Accepted'] = r['EANDM_Accepted'].replace(']', '').replace('[', '')
#     if (df.at[i, 'EANDM_Rejected'] != '') & (df.at[i, 'EANDM_Accepted'] != ''):
#         df.at[i, 'clean_suggested'] = df.at[i, 'EANDM_Accepted'] + ', ' + df.at[i, 'EANDM_Rejected']
#     else:
#        df.at[i, 'clean_suggested'] = df.at[i, 'EANDM_Accepted']  + df.at[i, 'EANDM_Rejected']
    
    
#     if (df.at[i, 'EANDM_Added'] != '') & (df.at[i, 'EANDM_Accepted'] != ''):
#         df.at[i, 'clean_final'] = df.at[i, 'EANDM_Accepted'] + ', ' + df.at[i, 'EANDM_Added']
#     else:
#        df.at[i, 'clean_final'] = df.at[i, 'EANDM_Accepted']  + df.at[i, 'EANDM_Added']

# %%
# for i,r in df.iterrows():
#     df.at[i, 'eandm_rejected'] = r['eandm_rejected'].replace(']', '').replace('[', '')
#     df.at[i, 'eandm_added'] = r['eandm_added'].replace(']', '').replace('[', '')
#     df.at[i, 'eandm_accepted'] = r['eandm_accepted'].replace(']', '').replace('[', '')
#     if (df.at[i, 'eandm_rejected'] != '') & (df.at[i, 'eandm_accepted'] != ''):
#         df.at[i, 'clean_suggested'] = df.at[i, 'eandm_accepted'] + ', ' + df.at[i, 'eandm_rejected']
#     else:
#        df.at[i, 'clean_suggested'] = df.at[i, 'eandm_accepted']  + df.at[i, 'eandm_rejected']
    
    
#     if (df.at[i, 'eandm_added'] != '') & (df.at[i, 'eandm_accepted'] != ''):
#         df.at[i, 'clean_final'] = df.at[i, 'eandm_accepted'] + ', ' + df.at[i, 'eandm_added']
#     else:
#        df.at[i, 'clean_final'] = df.at[i, 'eandm_accepted']  + df.at[i, 'eandm_added']

# %%
# for i,r in df.iterrows():
#     df.loc[i,'EANDM_Suggested_Code'] = ','.join([str(elem) for elem in re.findall(r"\b\d{5}\b", str(r['EANDM_Suggested']))])
#     df.loc[i,'EANDM_Final_Code'] = ','.join([str(elem) for elem in re.findall(r"\b\d{5}\b", str(r['EANDM_Final']))])

# %%
# df=df[['processingDate', 'serviceDate', 'encDocIds', 'accountNumber', 'EANDM_Suggested_Code', 'EANDM_Final_Code', 'local_suggested']]

# %%
df = df[df['local_suggested'].notna()]
df.shape
# Out:
# (1935, 6)

# %%
# df.local = df.local.astype('int')

# %%
df.local_suggested.value_counts()
# Out:
# 99285     977
# 99284     940
# 99282      17
# NoCode      1
# Name: local_suggested, dtype: int64

# %%
# df.suggested_code = df.suggested_code.astype('str')

# %%
# df = df[~df.suggested_code.str.contains('99291')]
# df.shape

# %%
def get_counts(x):
    
    suggested = str(x['local_suggested'])
    final = str(x['final_code'])
    
    if suggested != '':
        suggested_set = set(suggested.split(', '))
        final_set = set(final.split(','))
        if '9' not in suggested:
            final_set.clear()
        if '9' not in final:
            final_set.clear()
        if '99291' in suggested or '99291' in final:
            final_set.clear()
            suggested_set.clear()
        accepted = len(suggested_set.intersection(final_set))
        rejected = len(suggested_set - final_set)
        added = len(final_set - suggested_set)
        if (rejected >= 1 or added >= 1):
        
            print('rejected',rejected)
            print('added',added)
            print('suggested_set',suggested_set,'\t final_set',final_set)
            print('accountNumber', str(x['account_number']))
        return pd.Series({'accepted':accepted, 'rejected':rejected, 'added':added})

# %%
count_df =  df.apply(get_counts, axis=1)
# def get_accuracy()
# Out:
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90188798
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90155081
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90188787
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90188758
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90188766
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99292'}
# accountNumber 90122476
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90188870
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90188871
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 89947563
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90107935
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90107935
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207138
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90207128
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90207126
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207118
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207117
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207204
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207196
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207192
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207188
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90207171
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207150
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207148
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90172082
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207189
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207183
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90207166
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207161
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207189
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207183
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90207166
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207161
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90188869
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207220
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207209
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90207206
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90227057
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244716
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244715
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90244714
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90259967
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244710
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90259961
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244705
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90244704
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244703
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90259958
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244698
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244699
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90259949
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90227084
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90272750
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90272749
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90226967
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99283'}
# accountNumber 90227086
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90272729
# rejected 1
# added 1
# suggested_set {'99282'} 	 final_set {'99285'}
# accountNumber 90227075
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90272717
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90244675
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90272711
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90235399
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90235397
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90235390
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90252554
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90235381
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90252546
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90359419
# rejected 1
# added 1
# suggested_set {'99284'} 	 final_set {'99285'}
# accountNumber 90359416
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90359321
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90359290
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90395221
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90395094
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90272706
# rejected 1
# added 1
# suggested_set {'99285'} 	 final_set {'99284'}
# accountNumber 90415094

# %%
df2 = pd.concat([df, count_df], axis = 1)

# %%
# df2.drop(labels=['Unnamed: 0'],axis=1, inplace=True)

# %%
df2
# Out:
#       ocr_request_id  account_number  final_code  suggested_code  \
# 0            6675433        90188814       99285           99285
# 1            6675440        90188808       99284           99284
# 2            6675442        90188807       99285           99285
# 3            6675444        90188805       99291           99285
# 4            6675444        90188805       99285           99285
# ...              ...             ...         ...             ...
# 1930         6917619        90227081       99291           99291
# 1931         6917619        90227081       99285           99291
# 1932         6918839        90272706       99284           99284
# 1933         6922667        90415094       99284           99284
# 1934         6922666        90415173       99285           99284
#
#       local_suggested  accepted  rejected  added
# 0               99285         1         0      0
# 1               99284         1         0      0
# 2               99285         1         0      0
# 3               99285         0         0      0
# 4               99285         1         0      0
# ...               ...       ...       ...    ...
# 1930            99285         0         0      0
# 1931            99285         1         0      0
# 1932            99285         0         1      1
# 1933            99285         0         1      1
# 1934            99285         1         0      0
#
# [1935 rows x 8 columns]

# %%
df2.ocr_request_id = df2.ocr_request_id.astype('str')
df2.account_number = df2.account_number.astype('str')
df2.local_suggested = df2.local_suggested.astype('int')
df2.accepted = df2.accepted.astype('int')

# %%
# df2.reindex()
# df2.groupby(['account_number'], axis=0).agg(', '.join)

# %%
count_df.accepted.sum(), count_df.rejected.sum(), count_df.added.sum()
# Out:
# (1493, 336, 336)

# %%
precision = count_df.accepted.sum() / (count_df.accepted.sum() + count_df.rejected.sum())
recall = count_df.accepted.sum() / (count_df.accepted.sum() + count_df.added.sum())
f1_score = (2 * precision * recall) / (recall + precision)

# %%
data = {"precision":precision, "recall":recall, "f1_score":f1_score}
pd.Series(data).to_frame('new_overall_sheet_stats_local')
# Out:
#            new_overall_sheet_stats_local
# precision                       0.816293
# recall                          0.816293
# f1_score                        0.816293

# %%
# df.clean_final.value_counts()

# %%
# df.local_output_final.value_counts()

# %%
df.clean_suggested = df.clean_suggested.astype('str')
df.clean_final = df.clean_final.astype('str')
df.local_suggested = df.local_suggested.astype('str')

# %%
def highlight_same(data):
    
    highlighter = pd.DataFrame("", index=data.index, columns=data.columns)
    for col in data.columns:
        for index in data.index:

 

            if col == index:
                highlighter.loc[index, col] = 'background-color : springgreen'
                
            elif str(col)>str(index) and data.loc[index, col]>10:
                highlighter.loc[index, col] = 'background-color : lightskyblue'

            elif data.loc[index, col]>10:
                highlighter.loc[index, col] = 'background-color : PaleVioletRed'

    return highlighter

 

crosstab = cs.style.apply(highlight_same, axis=None)

# %%
crosstab.to_excel('/home/trishalaswain/ClientData/PH/CHINO_JULY_1_TO_10/CHINO_JULY_1_TO_10_local_crosstab.xlsx')

# %%
crosstab

# %%
df.clean_final.value_counts()

# %%
df.local_suggested_2 = df.local_suggested_2.astype('str')
df.clean_final = df.clean_final.astype('str')

# %%
new = df[(df.local_suggested_2.str.contains('99285')) & (df.clean_final.str.contains('99284'))]
new[['account_number', 'clean_final', 'clean_suggested', 'local_suggested_2']]

# %%
cols_to_use = ['service_date', 'account_number', 'facility_code', 'local_suggested', 'clean_suggested', 'clean_final']

# %%
df[df.clean_final.str.contains('99284') & df.local_suggested_2.str.contains('99285')][cols_to_use]

# %%
# confusion_matrix

# %%
# cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix, display_labels = df.clean_suggested.unique().tolist())

# %%
# confusion_matrix = pd.crosstab(df.clean_final, df.clean_suggested,margins = True, margins_name='Total')

# %%
# confusion_matrix.to_excel('/home/trishalaswain/ClientData/PH/CHINO_MONTH_WISE/CHINO_ALL_OP/25_MAY/test_matrix.xlsx')

# %%
# for i, r in df_fac.iterrows():
    
#     precision = df_fac.at[i,'accepted'] / (df_fac.at[i,'accepted'] + df_fac.at[i,'rejected'])
#     recall = df_fac.at[i,'accepted'] / (df_fac.at[i,'accepted'] + df_fac.at[i,'added'])
#     f1_score = (2 * precision * recall) / (recall + precision)
#     df_fac.at[i,'precision'] = precision
#     df_fac.at[i,'recall'] = recall
#     df_fac.at[i,'f1_score'] = f1_score

# %%
# df_fac

# %%
# df_fac.to_excel('/home/trishalaswain/Downloads/Script_Testing/excel_1.xlsx')

# %%
# precision, recall, f1_score

# %%
# def check_suggested(df):
#     for ind,row in df.iterrows():
#         row['new_suggested'] = str(row['new_suggested']).split(',')
#         for item in row['new_suggested']:
#             if str(item) == '{No Code}':
#                 df.at[ind,'rejected'] = 0
#                 continue
#             if str(item) in str(row['final']):
#                 df.at[ind,'accepted'] += 1
#             if str(item) not in str(row['final']):
#                 df.at[ind,'rejected'] +=1

# %%
# def check_final(df):
#     for ind,row in df.iterrows():
#         row['final'] = str(row['final']).split(',')
#         for final_code in row['final']:
#             if final_code not in str(row['new_suggested']):
#                 df.at[ind,'added'] +=1

# %%
# check_suggested(df)
# check_final(df)

# %%
# df['EANDM_Suggested_code'] = None

# %%
# def emsugg_filtered(df):
#     df['EANDM_Suggested_code'] = None
#     for ind, row in df.iterrows():

#         li = ast.literal_eval(row["EM_accepted"])
#         li2 = ast.literal_eval(row["EM_rejected"])
#         li3 = li + li2
#         df.at[ind,'EANDM_Suggested_code'] = li3

# %%
# emsugg_filtered(df)

# %%
# df

# %%
# def check_suggested2(df):
#     for ind,row in df.iterrows():
#         for item in row['EANDM_Suggested_code']:
#             if str(item) in str(row['final']):
#                 df.at[ind,'old_accepted'] += 1
#             if str(item) not in str(row['final']):
#                 df.at[ind,'old_rejected'] +=1

# %%
# def check_final2(df):
#     for ind,row in df.iterrows():
#         row['final'] = str(row['final']).split(',')
#         for final_code in row['final']:
#             if final_code not in str(row['EANDM_Suggested_code']):
#                 df.at[ind,'old_added'] +=1

# %%
# check_suggested2(df)
# check_final2(df)

# %%
# df2 = pd.read_excel('/home/trishalaswain/Downloads/Script_Testing/CHINO_ALL_TEXT_&_OUTPUT.xlsx', index_col=False)

# %%
# df2.final_code.value_counts()
