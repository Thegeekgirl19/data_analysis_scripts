# %%
import pymysql.cursors
import pandas as pd
connection = pymysql.connect(host='ezcapc-staging.cncmk5ndlbjo.us-east-1.rds.amazonaws.com', 
                             user='read_only', password='WHC63fKyjudfSz2U', db='CAPC_APIGATEWAY',
                             cursorclass=pymysql.cursors.SSDictCursor)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import pymysql.cursors
#       2 import pandas as pd
# ----> 3 connection = pymysql.connect(host='ezcapc-staging.cncmk5ndlbjo.us-east-1.rds.amazonaws.com',
#       4                              user='read_only', password='WHC63fKyjudfSz2U', db='CAPC_APIGATEWAY',
#       5                              cursorclass=pymysql.cursors.SSDictCursor)
#
# File ~/anaconda3/lib/python3.9/site-packages/pymysql/connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351     self._sock = None
#     352 else:
# --> 353     self.connect()
#
# File ~/anaconda3/lib/python3.9/site-packages/pymysql/connections.py:633, in Connection.connect(self, sock)
#     630 self._next_seq_id = 0
#     632 self._get_server_information()
# --> 633 self._request_authentication()
#     635 if self.sql_mode is not None:
#     636     c = self.cursor()
#
# File ~/anaconda3/lib/python3.9/site-packages/pymysql/connections.py:907, in Connection._request_authentication(self)
#     904     data += struct.pack("B", len(connect_attrs)) + connect_attrs
#     906 self.write_packet(data)
# --> 907 auth_packet = self._read_packet()
#     909 # if authentication method isn't accepted the first byte
#     910 # will have the octet 254
#     911 if auth_packet.is_auth_switch_request():
#
# File ~/anaconda3/lib/python3.9/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'read_only'@'10.120.0.94' (using password: YES)")

# %%
# conda install pymysql

# %%
connection

# %%
acc = []
for i in open('/home/trishalaswain/data_for_analysis/PH/Alvarado/encDocIds','r').readlines():
    acc.append(i.rstrip('\n'))

# %%
acc

# %%
len(acc)

# %%
# sql = """SELECT DISTINCT am.client_id, am.facility_id, dpd.eandmcs_request_id, am.account_number
# FROM
# account_mst am
# INNER JOIN
# document_mst dm ON am.id = dm.account_id and dm.is_physician_document = 1
# INNER JOIN
# document_processing_detail dpd ON dm.id = dpd.document_id
# WHERE
# am.account_number in({})
# order by dpd.created_date desc;""".format(",".join(str(x) for x in acc))

# %%
# String query = "SELECT DISTINCT am.client_id, am.facility_id, dpd.eandmcs_request_id, am.account_number, dpd.nlp_pcs_xml_result_s3_path, dpd.nlp_cdp_xml_result_s3_path,    dm.service_date FROM account_mst am     INNER JOIN document_mst dm ON am.id = dm.account_id and dm.is_physician_document = 1     INNER JOIN document_processing_detail dpd ON dm.id = dpd.document_id WHERE am.account_number = '"+Acclist.get(i)+"' AND dm.service_date like '%" + DOSlist.get(i) + "%' order by dpd.created_date desc;";

# %%
sql = """SELECT
 dm.id,
 dpd.nlp_request_s3_path,
 dpd.nlp_ner_entities_result_s3_path,
 dm.service_date FROM
 account_mst am


 JOIN
 document_mst dm ON dm.account_id = am.id
 AND dm.is_physician_document = 1

 JOIN
 document_processing_detail dpd ON dpd.document_id = dm.id 
 WHERE
 dm.id in ({})
 order by dpd.created_date desc;""".format(",".join(str(x) for x in acc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       1 sql = """SELECT
#       2  dm.id,
#       3  dpd.nlp_request_s3_path,
#       4  dpd.nlp_ner_entities_result_s3_path,
#       5  dm.service_date FROM
#       6  account_mst am
#       7
#       8
#       9  JOIN
#      10  document_mst dm ON dm.account_id = am.id
#      11  AND dm.is_physician_document = 1
#      12
#      13  JOIN
#      14  document_processing_detail dpd ON dpd.document_id = dm.id
#      15  WHERE
#      16  dm.id in ({})
# ---> 17  order by dpd.created_date desc;""".format(",".join(str(x) for x in acc))
#
# NameError: name 'acc' is not defined

# %%
# am.account_number,

# %%
sql_query = pd.read_sql(sql,con= connection)
# Out:
# /home/trishalaswain/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
sql_query
# Out:
#           id                                nlp_request_s3_path  \
# 0   28612841  ezcapc/PH/data/AHE/nlp/cdp-xml/20221227/601213...
# 1   28607200  ezcapc/PH/data/AHE/nlp/cdp-xml/20221220/601097...
# 2   28601533  ezcapc/PH/data/AHE/nlp/cdp-xml/20221211/600982...
# 3   28595812  ezcapc/PH/data/AHE/nlp/cdp-xml/20221208/600888...
# 4   28594776  ezcapc/PH/data/AHE/nlp/cdp-xml/20221207/600873...
# 5   28593067  ezcapc/PH/data/AHE/nlp/cdp-xml/20221113/600838...
# 6   28588188  ezcapc/PH/data/AHE/nlp/cdp-xml/20221118/600752...
# 7   28586709  ezcapc/PH/data/AHE/nlp/cdp-xml/20221106/600725...
# 8   28584528  ezcapc/PH/data/AHE/nlp/cdp-xml/20221105/600687...
# 9   28584453  ezcapc/PH/data/AHE/nlp/cdp-xml/20221103/600683...
# 10  27290885  ezcapc/PH/data/AHE/nlp/cdp-xml/20221223/576637...
# 11  25203114  ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/539606...
# 12  25133631  ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/538454...
# 13  25132565  ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/538448...
# 14  25054635  ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/537182...
# 15  24992337  ezcapc/PH/data/AHE/nlp/cdp-xml/20221230/536230...
# 16  24991047  ezcapc/PH/data/AHE/nlp/cdp-xml/20221230/536207...
# 17  24934399  ezcapc/PH/data/AHE/nlp/cdp-xml/20221229/535027...
# 18  24895464  ezcapc/PH/data/AHE/nlp/cdp-xml/20221229/534454...
# 19  24892530  ezcapc/PH/data/AHE/nlp/cdp-xml/20221229/534394...
# 20  24867070  ezcapc/PH/data/AHE/nlp/cdp-xml/20221228/533637...
# 21  24866190  ezcapc/PH/data/AHE/nlp/cdp-xml/20221228/533623...
# 22  24848609  ezcapc/PH/data/AHE/nlp/cdp-xml/20221228/533165...
# 23  24845620  ezcapc/PH/data/AHE/nlp/cdp-xml/20221227/533096...
# 24  24840354  ezcapc/PH/data/AHE/nlp/cdp-xml/20221227/533011...
# 25  24824515  ezcapc/PH/data/AHE/nlp/cdp-xml/20221227/532676...
# 26  24597493  ezcapc/PH/data/AHE/nlp/cdp-xml/20221226/528694...
# 27  24354059  ezcapc/PH/data/AHE/nlp/cdp-xml/20221224/524276...
# 28  24347795  ezcapc/PH/data/AHE/nlp/cdp-xml/20221224/524162...
# 29  24338618  ezcapc/PH/data/AHE/nlp/cdp-xml/20221224/524038...
# 30  24223941  ezcapc/PH/data/AHE/nlp/cdp-xml/20221223
sql_query.isna().sum()
# Out:
# id                                 0
# nlp_request_s3_path                0
# nlp_ner_entities_result_s3_path    0
# service_date                       0
# dtype: int64

# %%
sql_query=sql_query.dropna()

# %%
# sql_query.T

# %%
# cmd1 = []
# # name = str(account) + "_" + str(date)
# for eandmcs,entity,account,date in zip(sql_query.nlp_request_s3_path,sql_query.nlp_ner_entities_result_s3_path,sql_query.account_number,sql_query.service_date):
#     date = str(date).replace(' ','_')
#     cmd1.append("aws s3 cp s3://ezdi-production-bucket/"+str(eandmcs)+"    "+str(account) + "_" + str(date)+"_request.json")
#     cmd1.append("aws s3 cp s3://ezdi-production-bucket/"+str(entity)+"    "+str(account) + "_" + str(date)+"_result.json")

# %%
cmd1 = []
# name = str(account) + "_" + str(date)
for eandmcs,entity,enc_id in zip(sql_query.nlp_request_s3_path,sql_query.nlp_ner_entities_result_s3_path,sql_query.id):
    cmd1.append("aws s3 cp s3://ezdi-production-bucket/"+str(eandmcs)+"    "+ str(enc_id) + "_request.json")
    # cmd1.append("aws s3 cp s3://ezdi-production-bucket/"+str(entity)+"    "+ str(enc_id) + "_response.json")
    # cmd1.append("aws s3 cp s3://ezdi-production-bucket/"+str(entity)+"    "+str(account) + "_" + str(date)+"_result.json")

# %%
cmd1
# Out:
# ['aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221227/6012132_AH_DATE-01_30_23_CSN-7700081199807_20230131011956.056_request.json    28612841_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221220/6010976_AH_DATE-01_30_23_CSN-7700081081690_20230131003436.036_request.json    28607200_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221211/6009821_AH_DATE-01_30_23_CSN-7700080851844_20230130234134.034_request.json    28601533_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221208/6008883_AH_DATE-01_30_23_CSN-7700080789348_20230130225850.050_request.json    28595812_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221207/6008730_AH_DATE-01_30_23_CSN-7700080759080_20230130224827.027_request.json    28594776_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221113/6008385_AH_DATE-01_30_23_CSN-7700080228143_20230130223123.023_request.json    28593067_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221118/6007526_AH_DATE-01_30_23_CSN-7700080369198_20230130215149.049_request.json    28588188_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221106/6007254_AH_DATE-01_30_23_CSN-7700080074842_20230130213850.050_request.json    28586709_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221105/6006871_AH_DATE-01_30_23_CSN-7700080061212_20230130212053.053_request.json    28584528_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221103/6006839_AH_DATE-01_30_23_CSN-7700080025952_20230130211919.019_request.json    28584453_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221223/5766374_AH_DATE-01_19_23_CSN-7700081132415_20230119234418.018_request.json    27290885_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/5396064_AH_DATE-01_03_23_CSN-7700081296016_20230104070259.059_request.json    25203114_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/5384544_AH_DATE-01_03_23_CSN-7700081291196_20230103180310.010_request.json    25133631_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/5384489_AH_DATE-01_03_23_CSN-7700081285878_20230103180152.052_request.json    25132565_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221231/5371828_AH_DATE-01_03_23_CSN-7700081289875_20230103090154.054_request.json    25054635_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221230/5362301_AH_DATE-01_02_23_CSN-7700081272712_20230102200122.022_request.json    24992337_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221230/5362070_AH_DATE-01_02_23_CSN-7700081264496_20230102190243.043_request.json    24991047_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221229/5350275_AH_DATE-01_01_23_CSN-7700081226996_20230102103309.009_request.json    24934399_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221229/5344545_AH_DATE-01_01_23_CSN-7700081239453_20230102010117.017_request.json    24895464_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20221229/5343949_AH_DATE-01_01_23_CSN-7700081237763_20230101210047.047_request.json    24892530_request.json',
#  'aws s3 cp s3://ezdi-production-bucket/ezcapc/PH/data/AHE/nlp/cdp-xml/20